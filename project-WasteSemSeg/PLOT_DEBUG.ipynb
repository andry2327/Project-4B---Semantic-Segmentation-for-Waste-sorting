# %%
from utils import plot_mIoU_validation
import numpy as np

mIoU_list = np.log(np.arange(1, 101))
aluminum_mIoU_list = 0.9*np.log10(np.arange(1, 101))
paper_mIoU_list = 0.8*np.log(np.arange(1, 101))
bottle_mIoU_list = 0.7*np.log10(np.arange(1, 101))
nylon_mIoU_list = 0.6*np.log(np.arange(1, 101))

# %%
# mIoU_list, aluminum_mIoU_list, paper_mIoU_list, bottle_mIoU_list, nylon_mIoU_list

# %%
plot_mIoU_validation('net_str', mIoU_list, aluminum_mIoU_list, paper_mIoU_list, bottle_mIoU_list, nylon_mIoU_list, 100, 0.995, 5)
# Out:
# Plot ylim in [0, 1]
# Plot 4 classes
# Plot 4 classes, ylim in [0, 1]
